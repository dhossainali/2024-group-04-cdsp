# %%
import pandas as pd

DataFr=pd.read_csv('smmh.csv')

# %%
# Checking what are the columns name (variables name)

DataFr.columns
# Out:
# Index(['Timestamp', '1. What is your age?', '2. Gender',
#        '3. Relationship Status', '4. Occupation Status',
#        '5. What type of organizations are you affiliated with?',
#        '6. Do you use social media?',
#        '7. What social media platforms do you commonly use?',
#        '8. What is the average time you spend on social media every day?',
#        '9. How often do you find yourself using Social media without a specific purpose?',
#        '10. How often do you get distracted by Social media when you are busy doing something?',
#        '11. Do you feel restless if you haven't used Social media in a while?',
#        '12. On a scale of 1 to 5, how easily distracted are you?',
#        '13. On a scale of 1 to 5, how much are you bothered by worries?',
#        '14. Do you find it difficult to concentrate on things?',
#        '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
# ...

# %%
# Checking what the data look like

DataFr.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# ...

# %%
# To get a quick look at the basic statistics of the qualitative data (mean and standard deviation)

DataFr.describe()
# Out:
#        1. What is your age?  \
# count             481.00000
# mean               26.13659
# std                 9.91511
# min                13.00000
# 25%                21.00000
# 50%                22.00000
# 75%                26.00000
# max                91.00000
#
#        9. How often do you find yourself using Social media without a specific purpose?  \
# count                                         481.000000
# mean                                            3.553015
# std                                             1.096299
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        10. How often do you get distracted by Social media when you are busy doing something?  \
# count                                         481.000000
# ...

# %%
# Checking for the empty cell in the most relevant variables
#There are 30 empty cells in the type of Organization but we keep it like this because we do not analyze it

DataFr.isna().sum()
# Out:
# Timestamp                                                                                                                0
# 1. What is your age?                                                                                                     0
# 2. Gender                                                                                                                0
# 3. Relationship Status                                                                                                   0
# 4. Occupation Status                                                                                                     0
# 5. What type of organizations are you affiliated with?                                                                  30
# 6. Do you use social media?                                                                                              0
# 7. What social media platforms do you commonly use?                                                                      0
# ...

# %%
# Checking the frequency of the ages
# We can also catagorize the age (a suggestion)

DataFr[['1. What is your age?']].value_counts()
# Out:
# 1. What is your age?
# 21.0                    82
# 22.0                    81
# 20.0                    45
# 23.0                    42
# 24.0                    27
# 19.0                    19
# 26.0                    18
# 25.0                    17
# 47.0                    16
# 18.0                    13
# 48.0                    13
# 27.0                    11
# 17.0                     9
# 35.0                     8
# 29.0                     6
# 34.0                     6
# 30.0                     6
# 50.0                     6
# 28.0                     5
# 32.0                     4
# 14.0                     4
# 37.0                     4
# 49.0                     3
# 36.0                     3
# 38.0                     3
# 44.0                     2
# 51.0                     2
# 56.0                     2
# 46.0                     2
# 13.0                     2
# 40.0                     2
# 33.0                     2
# 16.0                     2
# ...

# %%
# Checking the frequency of the gender

DataFr[[ '2. Gender'
       ]].value_counts()
# Out:
# 2. Gender
# Female                 263
# Male                   211
# NB                       1
# Non binary               1
# Non-binary               1
# Nonbinary                1
# There are others???      1
# Trans                    1
# unsure                   1
# dtype: int64

# %%
# Doing some data cleaning, replacing the data with same name but with different spelling

DataFr.replace({'2. Gender': {'NB': 'Non binary', 'Non-binary': 'Non binary','Non binary ': 'Non binary','Nonbinary ': 'Non binary' }}, inplace=True)

# %%
# Checking the result of cleaning
DataFr[[ '2. Gender'
       ]].value_counts()
# Out:
# 2. Gender
# Female                 263
# Male                   211
# Non binary               4
# There are others???      1
# Trans                    1
# unsure                   1
# dtype: int64

# %%
# Checking the frequency of the Relationship status

DataFr[[
       '3. Relationship Status']].value_counts()
# Out:
# 3. Relationship Status
# Single                    285
# Married                   101
# In a relationship          88
# Divorced                    7
# dtype: int64

# %%
# Checking the frequency of the Occupation Status

DataFr[[ '4. Occupation Status',
       ]].value_counts()
# Out:
# 4. Occupation Status
# University Student      292
# Salaried Worker         132
# School Student           49
# Retired                   8
# dtype: int64

# %%
# Checking the frequency of Type of Organization

DataFr[['5. What type of organizations are you affiliated with?',
       ]].value_counts()
# Out:
# 5. What type of organizations are you affiliated with?
# University                                                239
# Private                                                    60
# School                                                     44
# Company                                                    30
# University, Company                                        19
# University, Private                                        16
# School, University                                          9
# Company, Private                                            7
# Goverment                                                   6
# University, Company, Private                                5
# School, University, Private                                 4
# University, N/A                                             3
# School, N/A                                                 2
# School, Company                                             2
# ...

# %%
# Checking the frequency of those with social media usage and those who don't
# We can see that those who do not use social media is below one percent

DataFr[[ '6. Do you use social media?'
       ]].value_counts()
# Out:
# 6. Do you use social media?
# Yes                            478
# No                               3
# dtype: int64

# %%
# Checking the frequency of hour spent on social media
# we need to transfer it to quantitative data in order to analyze it.

DataFr[[ '8. What is the average time you spend on social media every day?'
       ]].value_counts()
# Out:
# 8. What is the average time you spend on social media every day?
# More than 5 hours                                                   116
# Between 2 and 3 hours                                               101
# Between 3 and 4 hours                                                93
# Between 1 and 2 hours                                                70
# Between 4 and 5 hours                                                67
# Less than an Hour                                                    34
# dtype: int64

# %%
# Here we are transfering hour spent on social media to average hour ( we select 6 for more than 5 hours)

DataFr.replace({'8. What is the average time you spend on social media every day?':{'More than 5 hours': 6, 
                                                                                  'Between 2 and 3 hours': 2.5,
                                                                                  'Between 3 and 4 hours': 3.5,
                                                                                  'Between 1 and 2 hours': 1.5,
                                                                                  'Between 4 and 5 hours': 4.5,
                                                                                  'Less than an Hour': 0.5}}, inplace=True)

# %%
# Checking how the trasfered time sopent on social media look like.

DataFr[[ '8. What is the average time you spend on social media every day?'
       ]].value_counts()
# Out:
# 8. What is the average time you spend on social media every day?
# 6.0                                                                 116
# 2.5                                                                 101
# 3.5                                                                  93
# 1.5                                                                  70
# 4.5                                                                  67
# 0.5                                                                  34
# dtype: int64

# %%
# Checking how the distribution of the time spent on social media looks like

DataFr[[ '8. What is the average time you spend on social media every day?'
       ]].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Looking how skewed the variables are

DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?",
       '12. On a scale of 1 to 5, how easily distracted are you?',
       '13. On a scale of 1 to 5, how much are you bothered by worries?',
       '14. Do you find it difficult to concentrate on things?',
       '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
       '16. Following the previous question, how do you feel about these comparisons, generally speaking?',
       '17. How often do you look to seek validation from features of social media?',
       '18. How often do you feel depressed or down?',
       '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
       '20. On a scale of 1 to 5, how often do you face issues regarding sleep?']].skew()
# Out:
# 8. What is the average time you spend on social media every day?                                                        0.066316
# 9. How often do you find yourself using Social media without a specific purpose?                                       -0.426229
# 10. How often do you get distracted by Social media when you are busy doing something?                                 -0.275961
# 11. Do you feel restless if you haven't used Social media in a while?                                                   0.352011
# 12. On a scale of 1 to 5, how easily distracted are you?                                                               -0.179691
# 13. On a scale of 1 to 5, how much are you bothered by worries?                                                        -0.506260
# 14. Do you find it difficult to concentrate on things?                                                                 -0.238051
# ...

# %%
# Generating a corration table of the question 8-20


DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?",
       '12. On a scale of 1 to 5, how easily distracted are you?',
       '13. On a scale of 1 to 5, how much are you bothered by worries?',
       '14. Do you find it difficult to concentrate on things?',
       '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
       '16. Following the previous question, how do you feel about these comparisons, generally speaking?',
       '17. How often do you look to seek validation from features of social media?',
       '18. How often do you feel depressed or down?',
       '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
       '20. On a scale of 1 to 5, how often do you face issues regarding sleep?']].corr()
# Out:
#                                                     8. What is the average time you spend on social media every day?  \
# 8. What is the average time you spend on social...                                           1.000000
# 9. How often do you find yourself using Social ...                                           0.388985
# 10. How often do you get distracted by Social m...                                           0.369578
# 11. Do you feel restless if you haven't used So...                                           0.395900
# 12. On a scale of 1 to 5, how easily distracted...                                           0.333833
# 13. On a scale of 1 to 5, how much are you both...                                           0.319258
# 14. Do you find it difficult to concentrate on ...                                           0.312428
# 15. On a scale of 1-5, how often do you compare...                                           0.193804
# ...

# %%
# Importing matplotlib for visualization purposes

import matplotlib as mplt

# %%
# Checkig how the scatter plot of time spent on social media and the interested variable looks like
# Here the interested variable is 'Feeling depressed or down'
# The scatter plot doesn't look inteseting and does not illustrate anything

DataFr.plot(kind='scatter', x='8. What is the average time you spend on social media every day?', y='18. How often do you feel depressed or down?')
# Out:
# <AxesSubplot:xlabel='8. What is the average time you spend on social media every day?', ylabel='18. How often do you feel depressed or down?'>

# %%
# Checkig how the scatter plot of time spent on social media and the interested variable looks like
# Here the interested variable is 'Being bothered by worries'
# The scatter plot doesn't look inteseting and does not illustrate anything

DataFr.plot(kind='scatter', x='8. What is the average time you spend on social media every day?', y='13. On a scale of 1 to 5, how much are you bothered by worries?')
# Out:
# <AxesSubplot:xlabel='8. What is the average time you spend on social media every day?', ylabel='13. On a scale of 1 to 5, how much are you bothered by worries?'>

# %%
# Checkig how the scatter plot of getting distracted by social media and the interested variable looks like
# Here the interested variable is 'feeling restless without using social media'
# The scatter plot doesn't look inteseting and does not illustrate anything

DataFr.plot(kind='scatter', x='10. How often do you get distracted by Social media when you are busy doing something?',y="11. Do you feel restless if you haven't used Social media in a while?" )
# Out:
# <AxesSubplot:xlabel='10. How often do you get distracted by Social media when you are busy doing something?', ylabel="11. Do you feel restless if you haven't used Social media in a while?">

# %%
# Checkig another scatter polt if it is different from other.
# The scatter plot doesn't look inteseting and does not illustrate anything

DataFr.plot(kind='scatter', x='10. How often do you get distracted by Social media when you are busy doing something?', y='12. On a scale of 1 to 5, how easily distracted are you?')
# Out:
# <AxesSubplot:xlabel='10. How often do you get distracted by Social media when you are busy doing something?', ylabel='12. On a scale of 1 to 5, how easily distracted are you?'>

# %%
# importing seaborn package enhance our visualization

import seaborn as sns

# %%
# Checking if scatter plot with the gender segregation make any difference


sns.scatterplot( x='10. How often do you get distracted by Social media when you are busy doing something?',
            y='12. On a scale of 1 to 5, how easily distracted are you?',
               data=DataFr,
               hue='2. Gender')
# Out:
# <AxesSubplot:xlabel='10. How often do you get distracted by Social media when you are busy doing something?', ylabel='12. On a scale of 1 to 5, how easily distracted are you?'>

# %%
# Drawing a pairplot for the variables 8-14 and 18 based on gender

sns.pairplot(DataFr, vars=['8. What is the average time you spend on social media every day?',
                          '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?",
       '12. On a scale of 1 to 5, how easily distracted are you?',
       '13. On a scale of 1 to 5, how much are you bothered by worries?',
       '14. Do you find it difficult to concentrate on things?',
                          '18. How often do you feel depressed or down?'
                          ],hue='2. Gender')

# %%
# Drawing a pairplot for the variables 8-14 and 18 based on age

sns.pairplot(DataFr, vars=['8. What is the average time you spend on social media every day?',
                          '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?",
       '12. On a scale of 1 to 5, how easily distracted are you?',
       '13. On a scale of 1 to 5, how much are you bothered by worries?',
       '14. Do you find it difficult to concentrate on things?',
                          '18. How often do you feel depressed or down?'
                          ],hue='1. What is your age?')

# %%
# Ploting a regression line on variable 8 and 13

sns.lmplot(x='8. What is the average time you spend on social media every day?',
    y='13. On a scale of 1 to 5, how much are you bothered by worries?', data=DataFr)

# %%
# Ploting a regression line on variable 9 and 12

sns.lmplot(x='9. How often do you find yourself using Social media without a specific purpose?',
    y='12. On a scale of 1 to 5, how easily distracted are you?', data=DataFr)

# %%
# Ploting a regression line on variable 9 and 13

sns.lmplot(x='9. How often do you find yourself using Social media without a specific purpose?',
    y='13. On a scale of 1 to 5, how much are you bothered by worries?', data=DataFr)

# %%
# Importing some functions from sklearn package to run linear regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#Running regression while Y=how much one is bothered by worries and X=average time spent on social media per day
# And Finding R squared.

model=LinearRegression()
model.fit(DataFr[['8. What is the average time you spend on social media every day?']], DataFr[['13. On a scale of 1 to 5, how much are you bothered by worries?']] )
intercept=model.intercept_
coeffecient=model.coef_
print('Intercentp:' , intercept, 'Coefficeint:', coeffecient)
yPred=model.predict(DataFr[['8. What is the average time you spend on social media every day?']])
r2Score=r2_score( DataFr[['13. On a scale of 1 to 5, how much are you bothered by worries?']]
, yPred)
print('R-Squre:',r2Score)
# Out:
# Intercentp: [2.73539833] Coefficeint: [[0.2334453]]
# R-Squre: 0.1019255860752677

# %%
#Running regression while Y=feeling restless if one does not used social media in a while  and X=average time spent on social media per day
# And Finding R squared.

model1=LinearRegression()
model1.fit(DataFr[['8. What is the average time you spend on social media every day?']], DataFr[["11. Do you feel restless if you haven't used Social media in a while?"]] )
intercept1=model1.intercept_
coeffecient1=model1.coef_
print('Intercentp:' , intercept1, 'Coefficeint:', coeffecient1)
yPred1=model1.predict(DataFr[['8. What is the average time you spend on social media every day?']])
r2Score1=r2_score( DataFr[["11. Do you feel restless if you haven't used Social media in a while?"]]
, yPred1)
print('R-Squre:',r2Score1)
# Out:
# Intercentp: [1.58766027] Coefficeint: [[0.28355547]]
# R-Squre: 0.15673715140902256

# %%
#Running regression while Y= How often finding oneself using social media without a specific purpose and X=average time spent on social media per day
# And Finding R squared.

model2=LinearRegression()
model2.fit(DataFr[['8. What is the average time you spend on social media every day?']], DataFr[['9. How often do you find yourself using Social media without a specific purpose?']] )
intercept2=model2.intercept_
coeffecient2=model2.coef_
print('Intercentp:' , intercept2, 'Coefficeint:', coeffecient2)
yPred2=model2.predict(DataFr[['8. What is the average time you spend on social media every day?']])
r2Score2=r2_score( DataFr[['9. How often do you find yourself using Social media without a specific purpose?']]
, yPred2)
print('R-Squre:',r2Score2)
# Out:
# Intercentp: [2.6955377] Coefficeint: [[0.24297282]]
# R-Squre: 0.15130900283371385

# %%
#Running regression while Y=how often one get distracted by social media when he/she is busy doing something and X=average time spent on social media per day
# And Finding R squared.

model3=LinearRegression()
model3.fit(DataFr[['8. What is the average time you spend on social media every day?']], DataFr[['10. How often do you get distracted by Social media when you are busy doing something?']] )
intercept3=model3.intercept_
coeffecient3=model3.coef_
print('Intercentp:' , intercept3, 'Coefficeint:', coeffecient3)
yPred3=model3.predict(DataFr[['8. What is the average time you spend on social media every day?']])
r2Score3=r2_score( DataFr[['10. How often do you get distracted by Social media when you are busy doing something?']]
, yPred3)
print('R-Squre:',r2Score3)
# Out:
# Intercentp: [2.33318195] Coefficeint: [[0.2796698]]
# R-Squre: 0.13658813127835312

# %%
#Running regression while Y=finding difficult to concentrate and X=average time spent on social media per day
# And Finding R squared.

model4=LinearRegression()
model4.fit(DataFr[['8. What is the average time you spend on social media every day?']], DataFr[['14. Do you find it difficult to concentrate on things?']] )
intercept4=model4.intercept_
coeffecient4=model4.coef_
print('Intercentp:' , intercept4, 'Coefficeint:', coeffecient4)
yPred4=model4.predict(DataFr[['8. What is the average time you spend on social media every day?']])
r2Score4=r2_score( DataFr[['14. Do you find it difficult to concentrate on things?']]
, yPred4)
print('R-Squre:',r2Score4)
# Out:
# Intercentp: [2.399045] Coefficeint: [[0.23979933]]
# R-Squre: 0.09761135683237965

# %%
#Running regression while Y=finding difficult to concentrate and X=varaibles 8, 9 and 10
# And Finding R squared.

model6=LinearRegression()
model6.fit(DataFr[['8. What is the average time you spend on social media every day?', '9. How often do you find yourself using Social media without a specific purpose?',
                 '10. How often do you get distracted by Social media when you are busy doing something?']], DataFr[['14. Do you find it difficult to concentrate on things?']] )
intercept6=model6.intercept_
coeffecient6=model6.coef_
print('Intercentp:' , intercept6, 'Coefficeint:', coeffecient6)
yPred6=model6.predict(DataFr[['8. What is the average time you spend on social media every day?', '9. How often do you find yourself using Social media without a specific purpose?',
                 '10. How often do you get distracted by Social media when you are busy doing something?']])
r2Score6=r2_score( DataFr[['14. Do you find it difficult to concentrate on things?']]
, yPred6)
print('R-Squre:',r2Score6)
# Out:
# Intercentp: [1.22003049] Coefficeint: [[0.1004561  0.02471992 0.47676566]]
# R-Squre: 0.294769366913074

# %%
#Running regression while Y=finding difficult to concentrate and X=varaibles 8, 10 and 11
# And Finding R squared.

model7=LinearRegression()
model7.fit(DataFr[['8. What is the average time you spend on social media every day?',
                
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?"]], DataFr[['14. Do you find it difficult to concentrate on things?']] )
intercept7=model7.intercept_
coeffecient7=model7.coef_
print('Intercentp:' , intercept7, 'Coefficeint:', coeffecient7)
yPred7=model7.predict(DataFr[['8. What is the average time you spend on social media every day?',
                 
       '10. How often do you get distracted by Social media when you are busy doing something?',
       "11. Do you feel restless if you haven't used Social media in a while?"]])
r2Score7=r2_score( DataFr[['14. Do you find it difficult to concentrate on things?']]
, yPred7)
print('R-Squre:',r2Score7)
# Out:
# Intercentp: [1.09653099] Coefficeint: [[0.05888161 0.37735287 0.26585103]]
# R-Squre: 0.33676886232263636

# %%
#Running regression while Y=finding difficult to concentrate and X=varaible 11
# And Finding R squared.

model8=LinearRegression()
model8.fit(DataFr[["11. Do you feel restless if you haven't used Social media in a while?"]], DataFr[['14. Do you find it difficult to concentrate on things?']] )
intercept8=model8.intercept_
coeffecient8=model8.coef_
print('Intercentp:' , intercept8, 'Coefficeint:', coeffecient8)
yPred8=model8.predict(DataFr[["11. Do you feel restless if you haven't used Social media in a while?"]])
r2Score8=r2_score( DataFr[['14. Do you find it difficult to concentrate on things?']]
, yPred8)
print('R-Squre:',r2Score8)
# Out:
# Intercentp: [1.94320462] Coefficeint: [[0.50306713]]
# R-Squre: 0.22037403603114603

# %%
#Running regression while Y=feeling depressed or down and X=varaibles 8, 9 and 10
# And Finding R squared.

model9=LinearRegression()
model9.fit(DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',"11. Do you feel restless if you haven't used Social media in a while?"]], DataFr[['18. How often do you feel depressed or down?']] )
intercept9=model9.intercept_
coeffecient9=model9.coef_
print('Intercentp:' , intercept9, 'Coefficeint:', coeffecient9)
yPred9=model9.predict(DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?',"11. Do you feel restless if you haven't used Social media in a while?"]])
r2Score9=r2_score( DataFr[['18. How often do you feel depressed or down?']]
, yPred9)
print('R-Squre:',r2Score9)
# Out:
# Intercentp: [1.34732099] Coefficeint: [[0.11812169 0.13858797 0.20406212 0.1242514 ]]
# R-Squre: 0.20547452427508028

# %%
#Running regression while  Y=feeling depressed or down and X=varaible 15
# And Finding R squared.

modelA=LinearRegression()
modelA.fit(DataFr[['15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?']], 
          DataFr[['18. How often do you feel depressed or down?']] )
interceptA=modelA.intercept_
coeffecientA=modelA.coef_
print('Intercentp:' , interceptA, 'Coefficeint:', coeffecientA)
yPredA=modelA.predict(DataFr[['15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?']])
r2ScoreA=r2_score( DataFr[['18. How often do you feel depressed or down?']]
, yPredA)
print('R-Squre:',r2ScoreA)
# Out:
# Intercentp: [2.15233696] Coefficeint: [[0.38966661]]
# R-Squre: 0.17455752408435932

# %%
#Running regression while Y=interest fluctuating and X=variable 15
# And Finding R squared.

modelA1=LinearRegression()
modelA1.fit(DataFr[['15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?']], 
          DataFr[['19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?']] )
interceptA1=modelA1.intercept_
coeffecientA1=modelA1.coef_
print('Intercentp:' , interceptA1, 'Coefficeint:', coeffecientA1)
yPredA1=modelA1.predict(DataFr[['15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?']])
r2ScoreA1=r2_score( DataFr[['19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?']]
, yPredA1)
print('R-Squre:',r2ScoreA1)
# Out:
# Intercentp: [2.22456097] Coefficeint: [[0.33405739]]
# R-Squre: 0.14005731548241362

# %%
#Running regression while  Y=facing issues regarding sleeping and X=varaibles 8, 9 and 10
# And Finding R squared.

modelA2=LinearRegression()
modelA2.fit(DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?'
       ]], 
          DataFr[['20. On a scale of 1 to 5, how often do you face issues regarding sleep?']] )
interceptA2=modelA2.intercept_
coeffecientA2=modelA2.coef_
print('Intercentp:' , interceptA2, 'Coefficeint:', coeffecientA2)
yPredA2=modelA2.predict(DataFr[['8. What is the average time you spend on social media every day?',
       '9. How often do you find yourself using Social media without a specific purpose?',
       '10. How often do you get distracted by Social media when you are busy doing something?'
       ]])
r2ScoreA2=r2_score( DataFr[['20. On a scale of 1 to 5, how often do you face issues regarding sleep?']]
, yPredA2)
print('R-Squre:',r2ScoreA2)
# Out:
# Intercentp: [1.68406591] Coefficeint: [[0.03741675 0.22476261 0.17678777]]
# R-Squre: 0.09257030667109678
